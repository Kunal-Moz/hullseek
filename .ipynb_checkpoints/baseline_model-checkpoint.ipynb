# %% [markdown]
# The goal of this notebook is to create a non-deep learning baseline model for classifying simplified level of fouling (SLoF) for a data set of underwater images.

# %%
import pandas as pd
import imageio.v2 as imageio
import torch
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import skimage.measure
import time
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from dtreeviz.trees import *

# %%
data_dir = 'data-biofouling/'
image_dir = 'data-biofouling/images/'
metadata_filename = 'metadata.csv'

# %%
# Loading the metadata csv file
df = pd.read_csv(data_dir + metadata_filename)

# %%
df.head(5)
# Out:
#               image.name  dataset.name  vessel.id niche.area  SLoF  \
# 0  000001-GNZuCtwed3.jpg  commercial-1          8       hull     0
# 1  000002-CAgNlUizNm.jpg  commercial-1          8       hull     0
# 2  000003-vDe7GN0NrL.jpg  commercial-1          8       hull     0
# 3  000004-TbUBpfn6iP.jpg  commercial-1          8       hull     0
# 4  000005-oemYWm1Tjg.jpg  commercial-1          8       hull     0
#
#    paint.quality     split
# 0              3  training
# 1              3  training
# 2              2  training
# 3              2  training
# 4              3  training

# %%
# numerically encode categorical variables so that we can make a correlation matrix
df_encoded = df.copy()

for col in df_encoded.select_dtypes(include=["object", "category"]):
    df_encoded[col] = df_encoded[col].astype('category').cat.codes

# %%
df_encoded.head(5)
# Out:
#    image.name  dataset.name  vessel.id  niche.area  SLoF  paint.quality  split
# 0           0             1          8           5     0              3      0
# 1           1             1          8           5     0              3      0
# 2           2             1          8           5     0              2      0
# 3           3             1          8           5     0              2      0
# 4           4             1          8           5     0              3      0

# %%
# Load all of the images
image_filenames = df['image.name']
images = {}
for filename in image_filenames:
    images[filename] = imageio.imread(image_dir + filename)

# %%
# Some ways to measure complexity of an image
# -shannon entropy, implemented in skimage.shannon_entropy
# -gradient_energy, implemented below
# -variance of red/green/blue channels

def gradient_energy(img):
    if img.ndim == 3:
        img = img.mean(axis=2)
    gx, gy = np.gradient(img.astype(float))
    return np.mean(np.sqrt(gx**2 + gy**2))

def laplacian_variance(img):
    if img.ndim == 3:
        img = img.mean(axis=2)
    lap = -4*img + np.roll(img, 1, 0) + np.roll(img, -1, 0) + np.roll(img, 1, 1) + np.roll(img, -1, 1)
    return lap.var()

def channel_variances(img):
    # (red, green, blue)
    variances = np.var(img, axis=(0, 1)) 
    return tuple(variances)

# %%
# make an enlarged dataframe including the complexity metrics

entropy_list = []
gradient_energy_list = []
laplacian_variance_list = []
red_variance_list = []
green_variance_list = []
blue_variance_list = []

timing = True
if timing:
    j = 0
    total = len(image_filenames)
    t_0 = time.time()

for filename in image_filenames:
    img = images[filename]
    entropy_list.append(skimage.measure.shannon_entropy(img))
    gradient_energy_list.append(gradient_energy(img))
    laplacian_variance_list.append(laplacian_variance(img))
    
    r_var, g_var, b_var = channel_variances(img)
    red_variance_list.append(r_var)
    green_variance_list.append(g_var)
    blue_variance_list.append(b_var)

    if timing:
        j += 1
        if j % 500 == 0:
            print(f"Processed image {j} of {total}")
            t_1 = time.time()
            time_elapsed = t_1 - t_0
            avg_time = time_elapsed / j
            print(f"\tTime spent:", int(time_elapsed), "seconds")
            print(f"\tEstimated time remaining:", int((total-j)*avg_time), 'seconds\n') 
   
df_aug = df.copy()
df_aug['entropy'] = entropy_list
df_aug['gradient_energy'] = gradient_energy_list
df_aug['laplacian_var'] = laplacian_variance_list
df_aug['red_var'] = red_variance_list
df_aug['green_var'] = green_variance_list
df_aug['blue_var'] = blue_variance_list
# Out:
# Processed image 500 of 10263
# 	Time spent: 46 seconds
# 	Estimated time remaining: 908 seconds
#
# Processed image 1000 of 10263
# 	Time spent: 89 seconds
# 	Estimated time remaining: 831 seconds
#
# Processed image 1500 of 10263
# 	Time spent: 136 seconds
# 	Estimated time remaining: 799 seconds
#
# Processed image 2000 of 10263
# 	Time spent: 183 seconds
# 	Estimated time remaining: 759 seconds
#
# Processed image 2500 of 10263
# 	Time spent: 224 seconds
# 	Estimated time remaining: 697 seconds
#
# Processed image 3000 of 10263
# 	Time spent: 269 seconds
# 	Estimated time remaining: 651 seconds
#
# Processed image 3500 of 10263
# 	Time spent: 312 seconds
# 	Estimated time remaining: 604 seconds
#
# Processed image 4000 of 10263
# 	Time spent: 356 seconds
# 	Estimated time remaining: 558 seconds
#
# Processed image 4500 of 10263
# 	Time spent: 398 seconds
# 	Estimated time remaining: 510 seconds
#
# Processed image 5000 of 10263
# 	Time spent: 440 seconds
# 	Estimated time remaining: 464 seconds
#
# Processed image 5500 of 10263
# 	Time spent: 483 seconds
# 	Estimated time remaining: 418 seconds
#
# Processed image 6000 of 10263
# 	Time spent: 527 seconds
# 	Estimated time remaining: 374 seconds
#
# Processed image 6500 of 10263
# 	Time spent: 570 seconds
# 	Estimated time remaining: 330 seconds
#
# Processed image 7000 of 10263
# 	Time spent: 611 seconds
# 	Estimated time remaining: 285 seconds
#
# Processed image 7500 of 10263
# 	Time spent: 653 seconds
# 	Estimated time remaining: 240 seconds
#
# Processed image 8000 of 10263
# 	Time spent: 697 seconds
# 	Estimated time remaining: 197 seconds
#
# Processed image 8500 of 10263
# 	Time spent: 739 seconds
# 	Estimated time remaining: 153 seconds
#
# Processed image 9000 of 10263
# 	Time spent: 785 seconds
# 	Estimated time remaining: 110 seconds
#
# Processed image 9500 of 10263
# 	Time spent: 828 seconds
# 	Estimated time remaining: 66 seconds
#
# Processed image 10000 of 10263
# 	Time spent: 872 seconds
# 	Estimated time remaining: 22 seconds

# %%
df_aug.head(5)
# Out:
#               image.name  dataset.name  vessel.id niche.area  SLoF  \
# 0  000001-GNZuCtwed3.jpg  commercial-1          8       hull     0
# 1  000002-CAgNlUizNm.jpg  commercial-1          8       hull     0
# 2  000003-vDe7GN0NrL.jpg  commercial-1          8       hull     0
# 3  000004-TbUBpfn6iP.jpg  commercial-1          8       hull     0
# 4  000005-oemYWm1Tjg.jpg  commercial-1          8       hull     0
#
#    paint.quality     split   entropy  gradient_energy  laplacian_var  \
# 0              3  training  7.210319         4.478048     636.869978
# 1              3  training  7.272785         5.438474     651.793542
# 2              2  training  6.754425         3.899760     672.922542
# 3              2  training  6.805911         3.346528     638.983190
# 4              3  training  7.596727         5.017859     816.255540
#
#        red_var    green_var     blue_var
# 0  1167.255624  1246.322851   908.185944
# 1  1431.521255  1157.676356   896.145955
# 2   726.176904  2836.436721  3370.453269
# 3  1927.794439   800.957564   610.556934
# 4  3071.784278  4140.360718  4639.516300

# %%
df_train = df_aug[df_aug['split'] == 'training']
df_val = df_aug[df_aug['split'] == 'validation']

# %%
feature_columns = ['image.name','dataset.name','vessel.id','nichi.area','paint.quality','entropy','gradient_energy','laplacian_var','red_var','green_var','blue_var']
x = df_aug[feature_columns]
y = df_aug['SLoF']

random_forest = RandomForestRegressor(n_estimators = 100,
                                      max_samples = 0.5, # for each tree, use half the rows to train that tree
                                      max_features = 0.5, # for each tree, use half of the feature columsn to train that tree 
                                      max_depth = 5)

random_forest.fit(x,y)
